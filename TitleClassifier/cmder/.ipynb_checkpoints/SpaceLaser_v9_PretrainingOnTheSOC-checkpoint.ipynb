# %% [markdown]
# # Space Laser v9 - Pretraining On The SOC Manual

# %%
conda install pandas -y

# %%
# Three Sections: (at the moment)
# 1) Installation Commands
# 2) Initialization Cells
# 3) Training Loop

print("Hooray! Here we go!")

# lolol
# Out:
# Hooray! Here we go!

# %% [markdown]
# # Install Commands

# %%
conda install scikit-learn -y

# %%
conda install -c conda-forge tensorboard
# Out:
# Collecting package metadata (current_repodata.json): ...working... done
# Solving environment: ...working... done
#
# ## Package Plan ##
#
#   environment location: C:\ProgramData\anaconda3\envs\SpaceLaser_v9_launchPad
#
#   added / updated specs:
#     - tensorboard
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     abseil-cpp-20211102.0      |       h0e60522_0         2.3 MB  conda-forge
#     aiosignal-1.3.1            |     pyhd8ed1ab_0          12 KB  conda-forge
#     async-timeout-4.0.3        |     pyhd8ed1ab_0          11 KB  conda-forge
#     brotli-python-1.0.9        |  py311hd77b12b_7         310 KB
#     charset-normalizer-3.2.0   |     pyhd8ed1ab_0          45 KB  conda-forge
#     click-8.1.7                | win_pyh7428d3b_0          83 KB  conda-forge
#     cryptography-41.0.3        |  py311h89fc84f_0         1.2 MB
#     grpc-cpp-1.48.2            |       hfe90ff0_1        23.5 MB
#     grpcio-1.48.2              |  py311hfe90ff0_1         2.0 MB
#     importlib-metadata-6.8.0   |     pyha770c72_0          25 KB  conda-forge
#     markdown-3.4.4             |     pyhd8ed1ab_0          70 KB  conda-forge
#     pyasn1-0.5.0               |     pyhd8ed1ab_0          61 KB  conda-forge
#     pyasn1-modules-0.3.0       |     pyhd8ed1ab_0          93 KB  conda-forge
#     pyjwt-2.8.0                |     pyhd8ed1ab_0          24 KB  conda-forge
#     pyopenssl-23.2.0           |     pyhd8ed1ab_1         126 KB  conda-forge
#     pysocks-1.7.1              |     pyh0701188_6          19 KB  conda-forge
#     re2-2022.04.01             |       h0e60522_0         472 KB  conda-forge
#     requests-2.31.0            |     pyhd8ed1ab_0          55 KB  conda-forge
#     urllib3-2.0.5              |     pyhd8ed1ab_0          96 KB  conda-forge
#     werkzeug-2.3.7             |     pyhd8ed1ab_0         248 KB  conda-forge
#     win_inet_pton-1.1.0        |     pyhd8ed1ab_6           8 KB  conda-forge
#     zipp-3.17.0                |     pyhd8ed1ab_0          19 KB  conda-forge
#     ------------------------------------------------------------
#                                            Total:        30.7 MB
#
# The following NEW packages will be INSTALLED:
#
#   abseil-cpp         conda-forge/win-64::abseil-cpp-20211102.0-h0e60522_0
#   absl-py            conda-forge/noarch::absl-py-2.0.0-pyhd8ed1ab_0
#   aiohttp            pkgs/main/win-64::aiohttp-3.8.5-py311h2bbff1b_0
#   aiosignal          conda-forge/noarch::aiosignal-1.3.1-pyhd8ed1ab_0
#   async-timeout      conda-forge/noarch::async-timeout-4.0.3-pyhd8ed1ab_0
#   blinker            conda-forge/noarch::blinker-1.6.2-pyhd8ed1ab_0
#   brotli-python      pkgs/main/win-64::brotli-python-1.0.9-py311hd77b12b_7
#   c-ares             pkgs/main/win-64::c-ares-1.19.1-h2bbff1b_0
#   cachetools         conda-forge/noarch::cachetools-5.3.1-pyhd8ed1ab_0
#   certifi            conda-forge/noarch::certifi-2023.7.22-pyhd8ed1ab_0
#   charset-normalizer conda-forge/noarch::charset-normalizer-3.2.0-pyhd8ed1ab_0
#   click              conda-forge/noarch::click-8.1.7-win_pyh7428d3b_0
#   cryptography       pkgs/main/win-64::cryptography-41.0.3-py311h89fc84f_0
#   frozenlist         pkgs/main/win-64::frozenlist-1.3.3-py311h2bbff1b_0
#   google-auth        conda-forge/noarch::google-auth-2.23.2-pyhca7485f_0
#   google-auth-oauth~ conda-forge/noarch::google-auth-oauthlib-1.0.0-pyhd8ed1ab_1
#   grpc-cpp           pkgs/main/win-64::grpc-cpp-1.48.2-hfe90ff0_1
#   grpcio             pkgs/main/win-64::grpcio-1.48.2-py311hfe90ff0_1
#   importlib-metadata conda-forge/noarch::importlib-metadata-6.8.0-pyha770c72_0
#   libprotobuf        pkgs/main/win-64::libprotobuf-3.20.3-h23ce68f_0
#   markdown           conda-forge/noarch::markdown-3.4.4-pyhd8ed1ab_0
#   multidict          pkgs/main/win-64::multidict-6.0.2-py311h2bbff1b_0
#   oauthlib           conda-forge/noarch::oauthlib-3.2.2-pyhd8ed1ab_0
#   protobuf           conda-forge/win-64::protobuf-3.20.3-py311h1ea47a8_1
#   pyasn1             conda-forge/noarch::pyasn1-0.5.0-pyhd8ed1ab_0
#   pyasn1-modules     conda-forge/noarch::pyasn1-modules-0.3.0-pyhd8ed1ab_0
#   pyjwt              conda-forge/noarch::pyjwt-2.8.0-pyhd8ed1ab_0
#   pyopenssl          conda-forge/noarch::pyopenssl-23.2.0-pyhd8ed1ab_1
#   pysocks            conda-forge/noarch::pysocks-1.7.1-pyh0701188_6
#   python_abi         conda-forge/win-64::python_abi-3.11-2_cp311
#   pyu2f              conda-forge/noarch::pyu2f-0.1.5-pyhd8ed1ab_0
#   re2                conda-forge/win-64::re2-2022.04.01-h0e60522_0
#   requests           conda-forge/noarch::requests-2.31.0-pyhd8ed1ab_0
#   requests-oauthlib  conda-forge/noarch::requests-oauthlib-1.3.1-pyhd8ed1ab_0
#   rsa                conda-forge/noarch::rsa-4.9-pyhd8ed1ab_0
#   tensorboard        conda-forge/noarch::tensorboard-2.14.1-pyhd8ed1ab_0
#   tensorboard-data-~ conda-forge/win-64::tensorboard-data-server-0.7.0-py311h1ea47a8_1
#   urllib3            conda-forge/noarch::urllib3-2.0.5-pyhd8ed1ab_0
#   werkzeug           conda-forge/noarch::werkzeug-2.3.7-pyhd8ed1ab_0
#   win_inet_pton      conda-forge/noarch::win_inet_pton-1.1.0-pyhd8ed1ab_6
#   yarl               pkgs/main/win-64::yarl-1.8.1-py311h2bbff1b_0
#   zipp               conda-forge/noarch::zipp-3.17.0-pyhd8ed1ab_0
#
# The following packages will be SUPERSEDED by a higher-priority channel:
#
#   ca-certificates    pkgs/main::ca-certificates-2023.08.22~ --> conda-forge::ca-certificates-2023.7.22-h56e8100_0
#
#
#
# Downloading and Extracting Packages
#
# werkzeug-2.3.7       | 248 KB    |            |   0%
#
# click-8.1.7          | 83 KB     |            |   0%
#
#
# importlib-metadata-6 | 25 KB     |            |   0%
#
#
#
# grpcio-1.48.2        | 2.0 MB    |            |   0%
#
#
#
#
# async-timeout-4.0.3  | 11 KB     |            |   0%
#
#
#
#
#
# pyasn1-modules-0.3.0 | 93 KB     |            |   0%
#
#
#
#
#
#
# requests-2.31.0      | 55 KB     |            |   0%
#
#
#
#
#
#
#
# pyasn1-0.5.0         | 61 KB     |            |   0%
#
#
#
#
#
#
#
#
# win_inet_pton-1.1.0  | 8 KB      |            |   0%
#
#
#
#
#
#
#
#
#
# charset-normalizer-3 | 45 KB     |            |   0%
#
#
#
#
#
#
#
#
#
#
# aiosignal-1.3.1      | 12 KB     |            |   0%
#
#
#
#
#
#
#
#
#
#
#
# pyjwt-2.8.0          | 24 KB     |            |   0%
#
#
#
#
#
#
#
#
#
#
#
#
# zipp-3.17.0          | 19 KB     |            |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
# urllib3-2.0.5        | 96 KB     |            |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# grpc-cpp-1.48.2      | 23.5 MB   |            |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pyopenssl-23.2.0     | 126 KB    |            |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# brotli-python-1.0.9  | 310 KB    |            |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# cryptography-41.0.3  | 1.2 MB    |            |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# re2-2022.04.01       | 472 KB    |            |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
# click-8.1.7          | 83 KB     | #9         |  19%
# werkzeug-2.3.7       | 248 KB    | 6          |   6%
#
#
# importlib-metadata-6 | 25 KB     | ######3    |  63%
#
#
#
#
# async-timeout-4.0.3  | 11 KB     | ########## | 100%
#
#
#
# grpcio-1.48.2        | 2.0 MB    |            |   1%
#
#
#
#
#
# pyasn1-modules-0.3.0 | 93 KB     | #7         |  17%
#
#
#
#
#
#
# requests-2.31.0      | 55 KB     | ##8        |  29%
#
#
#
#
#
#
#
# pyasn1-0.5.0         | 61 KB     | ##6        |  26%
#
#
#
#
#
#
#
#
# win_inet_pton-1.1.0  | 8 KB      | ########## | 100%
#
#
#
#
#
#
#
#
#
# charset-normalizer-3 | 45 KB     | ###5       |  36%
#
#
#
#
#
#
#
#
#
#
# aiosignal-1.3.1      | 12 KB     | ########## | 100%
#
#
# importlib-metadata-6 | 25 KB     | ########## | 100%
#
#
#
#
#
#
#
#
#
#
#
#
# zipp-3.17.0          | 19 KB     | ########6  |  86%
#
# click-8.1.7          | 83 KB     | ########## | 100%
#
#
#
#
#
#
#
#
#
#
#
# pyjwt-2.8.0          | 24 KB     | ######6    |  66%
#
# click-8.1.7          | 83 KB     | ########## | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pyopenssl-23.2.0     | 126 KB    | #2         |  13%
#
#
#
#
#
#
#
#
#
#
#
#
#
# urllib3-2.0.5        | 96 KB     | #6         |  17%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# grpc-cpp-1.48.2      | 23.5 MB   |            |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# cryptography-41.0.3  | 1.2 MB    | 1          |   1%
#
#
#
#
# async-timeout-4.0.3  | 11 KB     | ########## | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# brotli-python-1.0.9  | 310 KB    | 5          |   5%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# re2-2022.04.01       | 472 KB    | 3          |   3%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# grpc-cpp-1.48.2      | 23.5 MB   | #3         |  14%
#
#
#
#
#
#
# requests-2.31.0      | 55 KB     | ########## | 100%
#
#
#
#
#
#
# requests-2.31.0      | 55 KB     | ########## | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# grpc-cpp-1.48.2      | 23.5 MB   | ###3       |  34%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# grpc-cpp-1.48.2      | 23.5 MB   | ####9      |  50%
# werkzeug-2.3.7       | 248 KB    | ########## | 100%
# werkzeug-2.3.7       | 248 KB    | ########## | 100%
#
#
#
#
#
#
#
# pyasn1-0.5.0         | 61 KB     | ########## | 100%
#
#
#
#
#
#
#
# pyasn1-0.5.0         | 61 KB     | ########## | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# grpc-cpp-1.48.2      | 23.5 MB   | ######6    |  67%
#
#
#
#
#
#
#
#
# win_inet_pton-1.1.0  | 8 KB      | ########## | 100%
#
#
#
#
#
# pyasn1-modules-0.3.0 | 93 KB     | ########## | 100%
#
#
#
#
#
# pyasn1-modules-0.3.0 | 93 KB     | ########## | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# grpc-cpp-1.48.2      | 23.5 MB   | ########7  |  88%
#
#
#
#
#
#
#
#
#
# charset-normalizer-3 | 45 KB     | ########## | 100%
#
#
#
#
#
#
#
#
#
#
# aiosignal-1.3.1      | 12 KB     | ########## | 100%
#
#
#
#
#
#
#
#
#
# charset-normalizer-3 | 45 KB     | ########## | 100%
#
#
#
#
#
#
#
#
#
#
#
#
# zipp-3.17.0          | 19 KB     | ########## | 100%
#
#
#
#
#
#
#
#
#
#
#
# pyjwt-2.8.0          | 24 KB     | ########## | 100%
#
#
#
#
#
#
#
#
#
#
#
# pyjwt-2.8.0          | 24 KB     | ########## | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pyopenssl-23.2.0     | 126 KB    | ########## | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pyopenssl-23.2.0     | 126 KB    | ########## | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
# urllib3-2.0.5        | 96 KB     | ########## | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
# urllib3-2.0.5        | 96 KB     | ########## | 100%
#
#
#
# grpcio-1.48.2        | 2.0 MB    | ########## | 100%
#
#
#
# grpcio-1.48.2        | 2.0 MB    | ########## | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# brotli-python-1.0.9  | 310 KB    | ########## | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# brotli-python-1.0.9  | 310 KB    | ########## | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# re2-2022.04.01       | 472 KB    | ########## | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# re2-2022.04.01       | 472 KB    | ########## | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# cryptography-41.0.3  | 1.2 MB    | ########## | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# cryptography-41.0.3  | 1.2 MB    | ########## | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# grpc-cpp-1.48.2      | 23.5 MB   | ########## | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Preparing transaction: ...working... done
# Verifying transaction: ...working... done
# Executing transaction: ...working... done
#
# Note: you may need to restart the kernel to use updated packages.
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): repo.anaconda.com:443
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): conda.anaconda.org:443
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): repo.anaconda.com:443
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): repo.anaconda.com:443
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): repo.anaconda.com:443
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): repo.anaconda.com:443
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): conda.anaconda.org:443
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): repo.anaconda.com:443
# DEBUG:urllib3.connectionpool:https://repo.anaconda.com:443 "GET /pkgs/msys2/win-64/current_repodata.json HTTP/1.1" 304 0
# DEBUG:urllib3.connectionpool:https://repo.anaconda.com:443 "GET /pkgs/r/noarch/current_repodata.json HTTP/1.1" 304 0
# DEBUG:urllib3.connectionpool:https://repo.anaconda.com:443 "GET /pkgs/main/win-64/current_repodata.json HTTP/1.1" 304 0
# DEBUG:urllib3.connectionpool:https://repo.anaconda.com:443 "GET /pkgs/r/win-64/current_repodata.json HTTP/1.1" 304 0
# DEBUG:urllib3.connectionpool:https://repo.anaconda.com:443 "GET /pkgs/msys2/noarch/current_repodata.json HTTP/1.1" 304 0
# DEBUG:urllib3.connectionpool:https://conda.anaconda.org:443 "GET /conda-forge/noarch/current_repodata.json HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:https://repo.anaconda.com:443 "GET /pkgs/main/noarch/current_repodata.json HTTP/1.1" 304 0
# DEBUG:urllib3.connectionpool:https://conda.anaconda.org:443 "GET /conda-forge/win-64/current_repodata.json HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): conda.anaconda.org:443
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): conda.anaconda.org:443
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): conda.anaconda.org:443
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): repo.anaconda.com:443
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): conda.anaconda.org:443
# DEBUG:urllib3.connectionpool:https://conda.anaconda.org:443 "GET /conda-forge/noarch/click-8.1.7-win_pyh7428d3b_0.conda HTTP/1.1" 200 85051
# DEBUG:urllib3.connectionpool:https://conda.anaconda.org:443 "GET /conda-forge/noarch/werkzeug-2.3.7-pyhd8ed1ab_0.conda HTTP/1.1" 200 254193
# DEBUG:urllib3.connectionpool:https://conda.anaconda.org:443 "GET /conda-forge/noarch/importlib-metadata-6.8.0-pyha770c72_0.conda HTTP/1.1" 200 25910
# DEBUG:urllib3.connectionpool:https://conda.anaconda.org:443 "GET /conda-forge/noarch/async-timeout-4.0.3-pyhd8ed1ab_0.conda HTTP/1.1" 200 11352
# DEBUG:urllib3.connectionpool:https://repo.anaconda.com:443 "GET /pkgs/main/win-64/grpcio-1.48.2-py311hfe90ff0_1.conda HTTP/1.1" 200 2123746
# DEBUG:urllib3.connectionpool:https://conda.anaconda.org:443 "GET /conda-forge/noarch/pyasn1-modules-0.3.0-pyhd8ed1ab_0.conda HTTP/1.1" 200 95605
# DEBUG:urllib3.connectionpool:https://conda.anaconda.org:443 "GET /conda-forge/noarch/requests-2.31.0-pyhd8ed1ab_0.conda HTTP/1.1" 200 56690
# DEBUG:urllib3.connectionpool:https://conda.anaconda.org:443 "GET /conda-forge/noarch/pyasn1-0.5.0-pyhd8ed1ab_0.conda HTTP/1.1" 200 62934
# DEBUG:urllib3.connectionpool:https://conda.anaconda.org:443 "GET /conda-forge/noarch/win_inet_pton-1.1.0-pyhd8ed1ab_6.tar.bz2 HTTP/1.1" 200 8191
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): conda.anaconda.org:443
# DEBUG:urllib3.connectionpool:https://conda.anaconda.org:443 "GET /conda-forge/noarch/charset-normalizer-3.2.0-pyhd8ed1ab_0.conda HTTP/1.1" 200 45686
# DEBUG:urllib3.connectionpool:https://conda.anaconda.org:443 "GET /conda-forge/noarch/aiosignal-1.3.1-pyhd8ed1ab_0.tar.bz2 HTTP/1.1" 200 12730
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): repo.anaconda.com:443
# DEBUG:urllib3.connectionpool:https://conda.anaconda.org:443 "GET /conda-forge/noarch/zipp-3.17.0-pyhd8ed1ab_0.conda HTTP/1.1" 200 18954
# DEBUG:urllib3.connectionpool:https://conda.anaconda.org:443 "GET /conda-forge/noarch/pyjwt-2.8.0-pyhd8ed1ab_0.conda HTTP/1.1" 200 24809
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): repo.anaconda.com:443
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): repo.anaconda.com:443
# DEBUG:urllib3.connectionpool:https://conda.anaconda.org:443 "GET /conda-forge/noarch/pyopenssl-23.2.0-pyhd8ed1ab_1.conda HTTP/1.1" 200 129023
# DEBUG:urllib3.connectionpool:https://conda.anaconda.org:443 "GET /conda-forge/noarch/urllib3-2.0.5-pyhd8ed1ab_0.conda HTTP/1.1" 200 98371
# DEBUG:urllib3.connectionpool:https://repo.anaconda.com:443 "GET /pkgs/main/win-64/grpc-cpp-1.48.2-hfe90ff0_1.conda HTTP/1.1" 200 24594947
# DEBUG:urllib3.connectionpool:https://repo.anaconda.com:443 "GET /pkgs/main/win-64/cryptography-41.0.3-py311h89fc84f_0.conda HTTP/1.1" 200 1234443
# DEBUG:urllib3.connectionpool:https://repo.anaconda.com:443 "GET /pkgs/main/win-64/brotli-python-1.0.9-py311hd77b12b_7.conda HTTP/1.1" 200 317196
# DEBUG:urllib3.connectionpool:https://conda.anaconda.org:443 "GET /conda-forge/win-64/re2-2022.04.01-h0e60522_0.tar.bz2 HTTP/1.1" 200 482977
# DEBUG:urllib3.connectionpool:https://conda.anaconda.org:443 "GET /conda-forge/noarch/pysocks-1.7.1-pyh0701188_6.tar.bz2 HTTP/1.1" 200 19348
# DEBUG:urllib3.connectionpool:https://conda.anaconda.org:443 "GET /conda-forge/noarch/markdown-3.4.4-pyhd8ed1ab_0.conda HTTP/1.1" 200 71222
# DEBUG:urllib3.connectionpool:https://conda.anaconda.org:443 "GET /conda-forge/win-64/abseil-cpp-20211102.0-h0e60522_0.tar.bz2 HTTP/1.1" 200 2370353

# %%
pip install datetime
# Out:
# Looking in indexes: https://pypi.org/simple, https://pypi.ngc.nvidia.com
# Requirement already satisfied: datetime in c:\programdata\anaconda3\envs\spacelaser_v9_launchpad\lib\site-packages (5.2)
# Requirement already satisfied: zope.interface in c:\programdata\anaconda3\envs\spacelaser_v9_launchpad\lib\site-packages (from datetime) (6.0)
# Requirement already satisfied: pytz in c:\programdata\anaconda3\envs\spacelaser_v9_launchpad\lib\site-packages (from datetime) (2023.3.post1)
# Requirement already satisfied: setuptools in c:\programdata\anaconda3\envs\spacelaser_v9_launchpad\lib\site-packages (from zope.interface->datetime) (68.0.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
conda install transformers -y
# Out:
# Collecting package metadata (current_repodata.json): ...working... done
# Solving environment: ...working... done
#
# ## Package Plan ##
#
#   environment location: C:\ProgramData\anaconda3\envs\SpaceLaser_v9_launchPad
#
#   added / updated specs:
#     - transformers
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     arrow-cpp-11.0.0           |       ha81ea56_2         7.3 MB
#     aws-c-common-0.6.8         |       h2bbff1b_1         168 KB
#     aws-c-event-stream-0.1.6   |       hd77b12b_6          28 KB
#     aws-checksums-0.1.11       |       h2bbff1b_2          52 KB
#     aws-sdk-cpp-1.8.185        |       hd77b12b_1         2.9 MB
#     fsspec-2023.9.2            |  py311haa95532_0         355 KB
#     libcurl-8.1.1              |       h86230a5_0         332 KB
#     libevent-2.1.12            |       h56d1f94_1         417 KB
#     libssh2-1.10.0             |       he2ea4bf_2         236 KB
#     libthrift-0.15.0           |       h4364b78_2         777 KB
#     ------------------------------------------------------------
#                                            Total:        12.5 MB
#
# The following NEW packages will be INSTALLED:
#
#   arrow-cpp          pkgs/main/win-64::arrow-cpp-11.0.0-ha81ea56_2
#   aws-c-common       pkgs/main/win-64::aws-c-common-0.6.8-h2bbff1b_1
#   aws-c-event-stream pkgs/main/win-64::aws-c-event-stream-0.1.6-hd77b12b_6
#   aws-checksums      pkgs/main/win-64::aws-checksums-0.1.11-h2bbff1b_2
#   aws-sdk-cpp        pkgs/main/win-64::aws-sdk-cpp-1.8.185-hd77b12b_1
#   boost-cpp          pkgs/main/win-64::boost-cpp-1.82.0-h59b6b97_1
#   datasets           pkgs/main/win-64::datasets-2.12.0-py311haa95532_0
#   dill               pkgs/main/win-64::dill-0.3.6-py311haa95532_0
#   filelock           pkgs/main/win-64::filelock-3.9.0-py311haa95532_0
#   fsspec             pkgs/main/win-64::fsspec-2023.9.2-py311haa95532_0
#   gflags             pkgs/main/win-64::gflags-2.2.2-ha925a31_0
#   glog               pkgs/main/win-64::glog-0.5.0-hd77b12b_0
#   huggingface_hub    pkgs/main/win-64::huggingface_hub-0.15.1-py311haa95532_0
#   libboost           pkgs/main/win-64::libboost-1.82.0-hae598e9_1
#   libbrotlicommon    pkgs/main/win-64::libbrotlicommon-1.0.9-h2bbff1b_7
#   libbrotlidec       pkgs/main/win-64::libbrotlidec-1.0.9-h2bbff1b_7
#   libbrotlienc       pkgs/main/win-64::libbrotlienc-1.0.9-h2bbff1b_7
#   libcurl            pkgs/main/win-64::libcurl-8.1.1-h86230a5_0
#   libevent           pkgs/main/win-64::libevent-2.1.12-h56d1f94_1
#   libssh2            pkgs/main/win-64::libssh2-1.10.0-he2ea4bf_2
#   libthrift          pkgs/main/win-64::libthrift-0.15.0-h4364b78_2
#   lz4-c              pkgs/main/win-64::lz4-c-1.9.4-h2bbff1b_0
#   multiprocess       pkgs/main/win-64::multiprocess-0.70.14-py311haa95532_0
#   orc                pkgs/main/win-64::orc-1.7.4-h623e30f_1
#   pyarrow            pkgs/main/win-64::pyarrow-11.0.0-py311h8a3a540_1
#   python-xxhash      pkgs/main/win-64::python-xxhash-2.0.2-py311h2bbff1b_1
#   pyyaml             pkgs/main/win-64::pyyaml-6.0-py311h2bbff1b_1
#   regex              pkgs/main/win-64::regex-2022.7.9-py311h2bbff1b_0
#   responses          pkgs/main/noarch::responses-0.13.3-pyhd3eb1b0_0
#   safetensors        pkgs/main/win-64::safetensors-0.3.2-py311h062c2fa_0
#   snappy             pkgs/main/win-64::snappy-1.1.9-h6c2663c_0
#   tokenizers         pkgs/main/win-64::tokenizers-0.13.2-py311h49fca51_1
#   tqdm               pkgs/main/win-64::tqdm-4.65.0-py311h746a85d_0
#   transformers       pkgs/main/win-64::transformers-4.32.1-py311haa95532_0
#   utf8proc           pkgs/main/win-64::utf8proc-2.6.1-h2bbff1b_0
#   xxhash             pkgs/main/win-64::xxhash-0.8.0-h2bbff1b_3
#   yaml               pkgs/main/win-64::yaml-0.2.5-he774522_0
#   zstd               pkgs/main/win-64::zstd-1.5.5-hd43e919_0
#
# The following packages will be UPDATED:
#
#   ca-certificates    conda-forge::ca-certificates-2023.7.2~ --> pkgs/main::ca-certificates-2023.08.22-haa95532_0
#
# The following packages will be SUPERSEDED by a higher-priority channel:
#
#   certifi            conda-forge/noarch::certifi-2023.7.22~ --> pkgs/main/win-64::certifi-2023.7.22-py311haa95532_0
#
#
#
# Downloading and Extracting Packages
#
# aws-checksums-0.1.11 | 52 KB     |            |   0%
#
# aws-sdk-cpp-1.8.185  | 2.9 MB    |            |   0%
#
#
# libevent-2.1.12      | 417 KB    |            |   0%
#
#
#
# libssh2-1.10.0       | 236 KB    |            |   0%
#
#
#
#
# aws-c-common-0.6.8   | 168 KB    |            |   0%
#
#
#
#
#
# libcurl-8.1.1        | 332 KB    |            |   0%
#
#
#
#
#
#
# fsspec-2023.9.2      | 355 KB    |            |   0%
#
#
#
#
#
#
#
# aws-c-event-stream-0 | 28 KB     |            |   0%
#
#
#
#
#
#
#
#
# arrow-cpp-11.0.0     | 7.3 MB    |            |   0%
#
#
#
#
#
#
#
#
#
# libthrift-0.15.0     | 777 KB    |            |   0%
#
# aws-sdk-cpp-1.8.185  | 2.9 MB    | #2         |  13%
#
#
# libevent-2.1.12      | 417 KB    | 3          |   4%
# aws-checksums-0.1.11 | 52 KB     | ###        |  31%
#
#
#
#
# aws-c-common-0.6.8   | 168 KB    | 9          |   9%
#
#
#
#
#
# libcurl-8.1.1        | 332 KB    | 4          |   5%
#
#
#
#
#
#
# fsspec-2023.9.2      | 355 KB    | 4          |   5%
#
#
#
#
#
#
#
#
# arrow-cpp-11.0.0     | 7.3 MB    |            |   0%
#
#
#
#
#
#
#
# aws-c-event-stream-0 | 28 KB     | #####6     |  56%
# aws-checksums-0.1.11 | 52 KB     | ########## | 100%
#
#
#
#
#
#
#
#
#
# libthrift-0.15.0     | 777 KB    | 2          |   2%
#
#
#
#
#
#
#
#
# arrow-cpp-11.0.0     | 7.3 MB    | ######     |  61%
#
#
# libevent-2.1.12      | 417 KB    | ########## | 100%
#
#
# libevent-2.1.12      | 417 KB    | ########## | 100%
#
#
#
#
# aws-c-common-0.6.8   | 168 KB    | ########## | 100%
#
#
#
#
# aws-c-common-0.6.8   | 168 KB    | ########## | 100%
#
#
#
#
#
# libcurl-8.1.1        | 332 KB    | ########## | 100%
#
#
#
#
#
# libcurl-8.1.1        | 332 KB    | ########## | 100%
#
#
#
# libssh2-1.10.0       | 236 KB    | ########## | 100%
#
#
#
# libssh2-1.10.0       | 236 KB    | ########## | 100%
#
#
#
#
#
#
#
# aws-c-event-stream-0 | 28 KB     | ########## | 100%
#
#
#
#
#
#
#
# aws-c-event-stream-0 | 28 KB     | ########## | 100%
#
#
#
#
#
#
# fsspec-2023.9.2      | 355 KB    | ########## | 100%
#
#
#
#
#
#
# fsspec-2023.9.2      | 355 KB    | ########## | 100%
#
#
#
#
#
#
#
#
#
# libthrift-0.15.0     | 777 KB    | ########## | 100%
#
#
#
#
#
#
#
#
#
# libthrift-0.15.0     | 777 KB    | ########## | 100%
#
#
#
#
#
#
#
#
# arrow-cpp-11.0.0     | 7.3 MB    | ########## | 100%
#
#
#
#
#
#
#
#
# arrow-cpp-11.0.0     | 7.3 MB    | ########## | 100%
#
# aws-sdk-cpp-1.8.185  | 2.9 MB    | ########## | 100%
#
# aws-sdk-cpp-1.8.185  | 2.9 MB    | ########## | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Preparing transaction: ...working... done
# Verifying transaction: ...working... done
# Executing transaction: ...working... done
#
# Note: you may need to restart the kernel to use updated packages.
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): repo.anaconda.com:443
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): repo.anaconda.com:443
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): repo.anaconda.com:443
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): repo.anaconda.com:443
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): repo.anaconda.com:443
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): repo.anaconda.com:443
# DEBUG:urllib3.connectionpool:https://repo.anaconda.com:443 "GET /pkgs/msys2/noarch/current_repodata.json HTTP/1.1" 304 0
# DEBUG:urllib3.connectionpool:https://repo.anaconda.com:443 "GET /pkgs/msys2/win-64/current_repodata.json HTTP/1.1" 304 0
# DEBUG:urllib3.connectionpool:https://repo.anaconda.com:443 "GET /pkgs/main/win-64/current_repodata.json HTTP/1.1" 304 0
# DEBUG:urllib3.connectionpool:https://repo.anaconda.com:443 "GET /pkgs/r/noarch/current_repodata.json HTTP/1.1" 304 0
# DEBUG:urllib3.connectionpool:https://repo.anaconda.com:443 "GET /pkgs/main/noarch/current_repodata.json HTTP/1.1" 304 0
# DEBUG:urllib3.connectionpool:https://repo.anaconda.com:443 "GET /pkgs/r/win-64/current_repodata.json HTTP/1.1" 304 0
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): repo.anaconda.com:443
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): repo.anaconda.com:443
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): repo.anaconda.com:443
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): repo.anaconda.com:443
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): repo.anaconda.com:443
# DEBUG:urllib3.connectionpool:https://repo.anaconda.com:443 "GET /pkgs/main/win-64/aws-sdk-cpp-1.8.185-hd77b12b_1.conda HTTP/1.1" 200 3043151
# DEBUG:urllib3.connectionpool:https://repo.anaconda.com:443 "GET /pkgs/main/win-64/libssh2-1.10.0-he2ea4bf_2.conda HTTP/1.1" 200 241231
# DEBUG:urllib3.connectionpool:https://repo.anaconda.com:443 "GET /pkgs/main/win-64/libevent-2.1.12-h56d1f94_1.conda HTTP/1.1" 200 427386
# DEBUG:urllib3.connectionpool:https://repo.anaconda.com:443 "GET /pkgs/main/win-64/aws-checksums-0.1.11-h2bbff1b_2.conda HTTP/1.1" 200 52929
# DEBUG:urllib3.connectionpool:https://repo.anaconda.com:443 "GET /pkgs/main/win-64/aws-c-common-0.6.8-h2bbff1b_1.conda HTTP/1.1" 200 172530
# DEBUG:urllib3.connectionpool:https://repo.anaconda.com:443 "GET /pkgs/main/win-64/libcurl-8.1.1-h86230a5_0.conda HTTP/1.1" 200 340068
# DEBUG:urllib3.connectionpool:https://repo.anaconda.com:443 "GET /pkgs/main/win-64/fsspec-2023.9.2-py311haa95532_0.conda HTTP/1.1" 200 363028
# DEBUG:urllib3.connectionpool:https://repo.anaconda.com:443 "GET /pkgs/main/win-64/arrow-cpp-11.0.0-ha81ea56_2.conda HTTP/1.1" 200 7648757
# DEBUG:urllib3.connectionpool:https://repo.anaconda.com:443 "GET /pkgs/main/win-64/aws-c-event-stream-0.1.6-hd77b12b_6.conda HTTP/1.1" 200 29149
# DEBUG:urllib3.connectionpool:https://repo.anaconda.com:443 "GET /pkgs/main/win-64/libthrift-0.15.0-h4364b78_2.conda HTTP/1.1" 200 795293

# %%
conda install pytorch torchvision torchaudio cudatoolkit=11.8 -c pytorch -c nvidia
# Out:
# Collecting package metadata (current_repodata.json): ...working... done
# Solving environment: ...working... done
#
# # All requested packages already installed.
#
#
# Note: you may need to restart the kernel to use updated packages.
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): repo.anaconda.com:443
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): repo.anaconda.com:443
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): conda.anaconda.org:443
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): repo.anaconda.com:443
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): repo.anaconda.com:443
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): repo.anaconda.com:443
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): conda.anaconda.org:443
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): repo.anaconda.com:443
# DEBUG:urllib3.connectionpool:https://repo.anaconda.com:443 "GET /pkgs/r/win-64/current_repodata.json HTTP/1.1" 304 0
# DEBUG:urllib3.connectionpool:https://repo.anaconda.com:443 "GET /pkgs/main/noarch/current_repodata.json HTTP/1.1" 304 0
# DEBUG:urllib3.connectionpool:https://repo.anaconda.com:443 "GET /pkgs/msys2/win-64/current_repodata.json HTTP/1.1" 304 0
# DEBUG:urllib3.connectionpool:https://repo.anaconda.com:443 "GET /pkgs/msys2/noarch/current_repodata.json HTTP/1.1" 304 0
# DEBUG:urllib3.connectionpool:https://repo.anaconda.com:443 "GET /pkgs/r/noarch/current_repodata.json HTTP/1.1" 304 0
# DEBUG:urllib3.connectionpool:https://repo.anaconda.com:443 "GET /pkgs/main/win-64/current_repodata.json HTTP/1.1" 304 0
# DEBUG:urllib3.connectionpool:https://conda.anaconda.org:443 "GET /nvidia/win-64/current_repodata.json HTTP/1.1" 304 0
# DEBUG:urllib3.connectionpool:https://conda.anaconda.org:443 "GET /nvidia/noarch/current_repodata.json HTTP/1.1" 304 0

# %%
#CELL A: Load and Split the Data

import pandas as pd
from sklearn.model_selection import train_test_split

# Load the data
data = pd.read_csv("C://Offline_Storage//radiantClass//JobDesc_BlobText.csv")

# Split the data
train, temp = train_test_split(data, test_size=0.1, random_state=42)
val, test = train_test_split(temp, test_size=0.5, random_state=42)

# %%
#CELL B: Setting up the Model and Transformer

from transformers import BertTokenizer, BertForMaskedLM
from transformers import DataCollatorForLanguageModeling

# Load the tokenizer and model
tokenizer = BertTokenizer.from_pretrained("bert-base-uncased")
model = BertForMaskedLM.from_pretrained("bert-base-uncased")

# Data collator will help with constructing batches for training
data_collator = DataCollatorForLanguageModeling(
    tokenizer=tokenizer,
    mlm_probability=0.15  # 15% of tokens will be masked for prediction
)
# Out:
# Some weights of the model checkpoint at bert-base-uncased were not used when initializing BertForMaskedLM: ['bert.pooler.dense.weight', 'bert.pooler.dense.bias', 'cls.seq_relationship.bias', 'cls.seq_relationship.weight']
# - This IS expected if you are initializing BertForMaskedLM from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertForMaskedLM from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).

# %%
#CELL C: Tokenize the Data

train_encodings = tokenizer(list(train['JobDesc_BlobText']), truncation=True, padding='max_length', max_length=512)
val_encodings = tokenizer(list(val['JobDesc_BlobText']), truncation=True, padding='max_length', max_length=512)
test_encodings = tokenizer(list(test['JobDesc_BlobText']), truncation=True, padding='max_length', max_length=512)

# %%
#CELL D: Convert to Dataset and DataLoader

from torch.utils.data import Dataset, DataLoader

class JobTitleDataset(Dataset):
    def __init__(self, encodings):
        self.encodings = encodings

    def __getitem__(self, idx):
        return {key: val[idx] for key, val in self.encodings.items()}

    def __len__(self):
        return len(self.encodings.input_ids)

train_dataset = JobTitleDataset(train_encodings)
val_dataset = JobTitleDataset(val_encodings)
test_dataset = JobTitleDataset(test_encodings)

train_loader = DataLoader(train_dataset, shuffle=True, batch_size=8, collate_fn=data_collator)
val_loader = DataLoader(val_dataset, batch_size=8, collate_fn=data_collator)

# %%
#CELL E: Training Setup and Device Configuration
import torch
from torch.optim import AdamW

# Check for CUDA and move the model to GPU if available
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model.to(device)

# Setup optimizer
optimizer = AdamW(model.parameters(), lr=5e-5)

# %%
#CELL F: Verify that CUDA is available

print(f"Is Cuda available?: {torch.cuda.is_available()}! :-)")
print(f"CUDA version: {torch.version.cuda}")

# %%
#CELL Proto-G:

# %load_ext tensorboard

# %%
#CELL G: Set Up TensorBoard within the Notebook

# %tensorboard --logdir ./logs

# %%
#CELL H: Model Training Using Trainer

from transformers import TrainingArguments, Trainer

# Define training arguments
training_args = TrainingArguments(
    output_dir='./results',
    per_device_train_batch_size=8,  # Adjust batch size based on your GPU/CPU capacity
    per_device_eval_batch_size=8,  # Same for validation batch size
    num_train_epochs=3,  # Adjust the number of epochs based on your needs
    evaluation_strategy="epoch",
    logging_dir='./logs',
    logging_steps=10,
    do_train=True,
    do_eval=True,
    save_strategy="epoch",  # Save only the best model based on validation loss
    load_best_model_at_end=True,  # Load the best model at the end of training
    push_to_hub=False,  # Disable model hub push
)

# Initialize the Trainer
trainer = Trainer(
    model=model,
    args=training_args,
    train_dataset=train_dataset,
    eval_dataset=val_dataset,
    data_collator=data_collator  # Use the data_collator from CELL B
)

# Start training
trainer.train()
